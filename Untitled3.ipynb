# %%
def hell():
  printf('Hello, Python')

def say_hello(name,title):
  print(name = title = ' ,你好!')
# Out:
#   File "<ipython-input-1-c4d405da30f3>", line 5
#     print(name = title = ' ,你好!')
#                        ^
# SyntaxError: invalid syntax
