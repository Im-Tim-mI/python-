# %%
square = lambda x: x ** 2

num = int(input('請輸入一個整數: '))
print(f'{num}的平方等於{square(num)}')
# Out:
# 請輸入一個整數: 10
# 10的平方等於100

# %%
def square(x):
 return x**2
num = int(input('請輸入一個整數: '))
print(f'{num}的平方等於{square(num)}')
# Out:
# 請輸入一個整數: 10
# 10的平方等於100
