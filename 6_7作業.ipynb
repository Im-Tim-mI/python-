# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %%
eng_list = [90,92,88,76,100]
print(eng_list)
print(type(eng_list))
# Out:
# [90, 92, 88, 76, 100]
# <class 'list'>

# %%
eng_score = pd.Series(eng_list)
eng_score
# Out:
# 0     90
# 1     92
# 2     88
# 3     76
# 4    100
# dtype: int64

# %%
type(eng_score)
# Out:
# pandas.core.series.Series

# %%
name = ['郭鏡', '黃榕', '郭香', '張君葆', '揚過']
eng_score = pd.Series(eng_list, index=name)
eng_score
# Out:
# 郭鏡      90
# 黃榕      92
# 郭香      88
# 張君葆     76
# 揚過     100
# dtype: int64

# %%
math_dict = {"郭鏡": 96, "黄榕":98,"郭香": 78,"張君葆": 86, "楊過": 100}
name = math_dict.keys()
math_score = pd.Series(math_dict, index=name)
math_score
# Out:
# 郭鏡      96
# 黄榕      98
# 郭香      78
# 張君葆     86
# 楊過     100
# dtype: int64

# %%
type(math_score)
# Out:
# pandas.core.series.Series

# %%
man_grade = 100
std_index = range(5)
man_score = pd.Series(man_grade, index=std_index)
man_score
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
type(math_score)
# Out:
# pandas.core.series.Series

# %%
eng_score
# Out:
# 郭鏡      90
# 黃榕      92
# 郭香      88
# 張君葆     76
# 揚過     100
# dtype: int64

# %%
print (eng_score['郭鏡'])
print (eng_score[2])
# Out:
# 90
# 88

# %%
eng_score[[0,2,4]]
# Out:
# 郭鏡     90
# 郭香     88
# 揚過    100
# dtype: int64

# %%
eng_score[2:4]
# Out:
# 郭香     88
# 張君葆    76
# dtype: int64

# %%
math_score
# Out:
# 郭鏡      96
# 黄榕      98
# 郭香      78
# 張君葆     86
# 楊過     100
# dtype: int64

# %%
eng_score[:2]
# Out:
# 郭鏡    90
# 黃榕    92
# dtype: int64

# %%
math_score['郭香':]
# Out:
# 郭香      78
# 張君葆     86
# 楊過     100
# dtype: int64

# %%
import pandas as pd

# %%
std_list = [ ['郭鏡', 'jing@gmail.com', '0988123456'],
        ['黃榕', 'rong@gmail.com', '0989456321'],
        ['郭香', 'xiang@gmail.com', '0922337886'],
        ['張君葆', 'bao@gmail.com', '0933458972'],
        ['揚過', 'guo@gmail.com', '0927886493']
      ]

# %%
columns = ['姓名','email','手機']

# %%
std_id = ['S1001', 'S1002', 'S1003', 'S1004', 'S100']

# %%
std_df = pd.DataFrame(std_list, columns=columns, index=std_id)
std_df
# Out:
#         姓名            email          手機
# S1001   郭鏡   jing@gmail.com  0988123456
# S1002   黃榕   rong@gmail.com  0989456321
# S1003   郭香  xiang@gmail.com  0922337886
# S1004  張君葆    bao@gmail.com  0933458972
# S100    揚過    guo@gmail.com  0927886493

# %%
type(std_df)
# Out:
# pandas.core.frame.DataFrame

# %%
std_score_dict ={'name': ['郭鏡', '黄榕','郭香','張君葆','揚過'],
              'man_score':[100, 100, 100, 96, 98],
              'eng_score':[90, 92, 88, 76, 100],
              'math_score': [96, 98, 78, 86, 100]
              }

# %%
std_score_df = pd.DataFrame(std_score_dict, index=std_id)
std_score_df
# Out:
#       name  man_score  eng_score  math_score
# S1001   郭鏡        100         90          96
# S1002   黄榕        100         92          98
# S1003   郭香        100         88          78
# S1004  張君葆         96         76          86
# S100    揚過         98        100         100

# %%
type(std_score_df)
# Out:
# pandas.core.frame.DataFrame

# %%
std_score_df
# Out:
#       name  man_score  eng_score  math_score
# S1001   郭鏡        100         90          96
# S1002   黄榕        100         92          98
# S1003   郭香        100         88          78
# S1004  張君葆         96         76          86
# S100    揚過         98        100         100

# %%
std_score_df.shape
# Out:
# (5, 4)

# %%
std_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, S1001 to S100
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        5 non-null      object
#  1   man_score   5 non-null      int64
#  2   eng_score   5 non-null      int64
#  3   math_score  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 200.0+ bytes

# %%
std_score_df.describe()
# Out:
#         man_score   eng_score  math_score
# count    5.000000    5.000000    5.000000
# mean    98.800000   89.200000   91.600000
# std      1.788854    8.671793    9.316652
# min     96.000000   76.000000   78.000000
# 25%     98.000000   88.000000   86.000000
# 50%    100.000000   90.000000   96.000000
# 75%    100.000000   92.000000   98.000000
# max    100.000000  100.000000  100.000000

# %%
std_score_df.describe().T
# Out:
#             count  mean       std   min   25%    50%    75%    max
# man_score     5.0  98.8  1.788854  96.0  98.0  100.0  100.0  100.0
# eng_score     5.0  89.2  8.671793  76.0  88.0   90.0   92.0  100.0
# math_score    5.0  91.6  9.316652  78.0  86.0   96.0   98.0  100.0

# %%
std_score_df.head(3)
# Out:
#       name  man_score  eng_score  math_score
# S1001   郭鏡        100         90          96
# S1002   黄榕        100         92          98
# S1003   郭香        100         88          78

# %%
std_score_df.tail(3)
# Out:
#       name  man_score  eng_score  math_score
# S1003   郭香        100         88          78
# S1004  張君葆         96         76          86
# S100    揚過         98        100         100

# %%
std_score_df.columns
# Out:
# Index(['name', 'man_score', 'eng_score', 'math_score'], dtype='object')

# %%
std_score_df.index
# Out:
# Index(['S1001', 'S1002', 'S1003', 'S1004', 'S100'], dtype='object')

# %%
std_score_df.values
# Out:
# array([['郭鏡', 100, 90, 96],
#        ['黄榕', 100, 92, 98],
#        ['郭香', 100, 88, 78],
#        ['張君葆', 96, 76, 86],
#        ['揚過', 98, 100, 100]], dtype=object)

# %%
std_score_df['man_score']
# Out:
# S1001    100
# S1002    100
# S1003    100
# S1004     96
# S100      98
# Name: man_score, dtype: int64

# %%
std_score_df[['man_score','eng_score','math_score']]
# Out:
#        man_score  eng_score  math_score
# S1001        100         90          96
# S1002        100         92          98
# S1003        100         88          78
# S1004         96         76          86
# S100          98        100         100

# %%
std_score_df.loc['S1002', 'man_score':'math_score']
# Out:
# man_score     100
# eng_score      92
# math_score     98
# Name: S1002, dtype: object

# %%
std_score_df.loc['S1001', 'man_score']
# Out:
# 100

# %%
std_score_df.loc['S1003':, 'eng_score']
# Out:
# S1003     88
# S1004     76
# S100     100
# Name: eng_score, dtype: int64

# %%
std_df.loc[:, :]
# Out:
#         姓名            email          手機
# S1001   郭鏡   jing@gmail.com  0988123456
# S1002   黃榕   rong@gmail.com  0989456321
# S1003   郭香  xiang@gmail.com  0922337886
# S1004  張君葆    bao@gmail.com  0933458972
# S100    揚過    guo@gmail.com  0927886493

# %%
std_df.iloc[0, :]
# Out:
# 姓名                   郭鏡
# email    jing@gmail.com
# 手機           0988123456
# Name: S1001, dtype: object

# %%
std_df.iloc[-1,1]
# Out:
# 'guo@gmail.com'

# %%
std_df.iloc[2:4, 0]
# Out:
# S1003     郭香
# S1004    張君葆
# Name: 姓名, dtype: object
